# %%
import synapseclient
from synapseclient import Project, File, Folder
from synapseclient import Schema, Column, Table, Row, RowSet, as_table_columns
import itertools
import pandas as pd
import numpy as np

# %%
syn = synapseclient.Synapse()
syn.login()
# Out:
# Welcome, Victor Baham!

# %% [markdown]
# ### Provide breakdown of AMP-AD 1.0 and AMP-AD 2.0 stats combined

# %% [markdown]
# #### AMP-AD 1.0: ROSMAP, MSBB, MayoRNAseq

# %%
rosmap_bio = pd.read_csv(syn.get('syn21323366').path)
msbb_bio = pd.read_csv(syn.get('syn21893059').path)
mayo_bio = pd.read_csv(syn.get('syn20827192').path)

# %% [markdown]
# #### AMP-AD 2.0: Diverse Cohorts, NPS-AD where cohort != "HBCC"

# %%
divco_bio = pd.read_csv(syn.get('syn51757645').path)
nps_bio = pd.read_csv(syn.get('syn55251032').path)
nps_ind = pd.read_csv(syn.get('syn55251012').path)

# %% [markdown]
# #### nps_bio and nps_ind are joined to obtain the gold NPS metadata set so that the specimens where cohort != "HBCC" can be filtered out
#
# #### also, it is helpful to define the columns that are present in the NPS biospecimen metadata set to drop any extraneous columns in the gold NPS metadata set

# %%
nps_gold = pd.merge(nps_ind, nps_bio, on='individualID')
nps_cols_keep = nps_bio.columns.tolist()
nps_cols_keep = ['individualID',
 'specimenID',
 'specimenIdSource',
 'organ',
 'tissue',
 'isPostMortem',
 'BrodmannArea',
 'nucleicAcidSource',
 'cellType',
 'samplingAge',
 'samplingAgeUnits',
 'sampleStatus',
 'fastingState',
 'visitNumber',
 'assay',
 'Id',
 'entityId']

# %%
nps_filter_out_hbcc = (nps_gold['cohort'] != 'HBCC')
nps_bio_by_cohort = nps_gold[nps_filter_out_hbcc]
nps_bio_by_cohort = nps_bio_by_cohort[nps_bio_by_cohort.columns[nps_bio_by_cohort.columns.isin(['individualID',
 'specimenID',
 'specimenIdSource',
 'organ',
 'tissue',
 'isPostMortem',
 'BrodmannArea',
 'nucleicAcidSource',
 'cellType',
 'samplingAge',
 'samplingAgeUnits',
 'sampleStatus',
 'fastingState',
 'visitNumber',
 'assay',
 'Id',
 'entityId'])]].reset_index(drop=True)

# %% [markdown]
# ### AMP-AD_1.0 golden biospecimen metadata:

# %%
amp_ad_1_gold = pd.concat([rosmap_bio, msbb_bio, mayo_bio]).reset_index(drop=True)

# %% [markdown]
# #### Add column `AMP-AD_phase` to denote this data belonging to AMP-AD_1.0

# %%
amp_ad_1_gold['AMP-AD_phase'] = 'AMP-AD_1.0'

# %% [markdown]
# #### Inspect for rows where `specimenID` is null:

# %%
amp_ad_1_gold[amp_ad_1_gold['specimenID'].isna()]
# Out:
#       individualID specimenID specimenIdSource organ tissue BrodmannArea  \
# 16879          NaN        NaN              NaN   NaN    NaN          NaN
# 16880          NaN        NaN              NaN   NaN    NaN          NaN
# 16881          NaN        NaN              NaN   NaN    NaN          NaN
# 16882          NaN        NaN              NaN   NaN    NaN          NaN
# 16883          NaN        NaN              NaN   NaN    NaN          NaN
# ...            ...        ...              ...   ...    ...          ...
# 19656          NaN        NaN              NaN   NaN    NaN          NaN
# 19657          NaN        NaN              NaN   NaN    NaN          NaN
# 19658          NaN        NaN              NaN   NaN    NaN          NaN
# 19659          NaN        NaN              NaN   NaN    NaN          NaN
# 19660          NaN        NaN              NaN   NaN    NaN          NaN
#
#       sampleStatus  tissueWeight  tissueVolume nucleicAcidSource  ...  \
# 16879          NaN           NaN           NaN               NaN  ...
# 16880          NaN           NaN           NaN               NaN  ...
# 16881          NaN           NaN           NaN               NaN  ...
# 16882          NaN           NaN           NaN               NaN  ...
# 16883          NaN           NaN           NaN               NaN  ...
# ...            ...           ...           ...               ...  ...
# 19656          NaN           NaN           NaN               NaN  ...
# 19657          NaN           NaN           NaN               NaN  ...
# 19658          NaN           NaN           NaN               NaN  ...
# 19659          NaN           NaN           NaN               NaN  ...
# 19660          NaN           NaN           NaN               NaN  ...
#
#       isPostMortem samplingAge samplingAgeUnits visitNumber assay  exclude  \
# 16879          NaN         NaN              NaN         NaN   NaN      NaN
# 16880          NaN         NaN              NaN         NaN   NaN      NaN
# 16881          NaN         NaN              NaN         NaN   NaN      NaN
# 16882          NaN         NaN              NaN         NaN   NaN      NaN
# 16883          NaN         NaN              NaN         NaN   NaN      NaN
# ...            ...         ...              ...         ...   ...      ...
# 19656          NaN         NaN              NaN         NaN   NaN      NaN
# 19657          NaN         NaN              NaN         NaN   NaN      NaN
# 19658          NaN         NaN              NaN         NaN   NaN      NaN
# 19659          NaN         NaN              NaN         NaN   NaN      NaN
# 19660          NaN         NaN              NaN         NaN   NaN      NaN
#
#       excludeReason samplingDate Exclusion_Category  AMP-AD_phase
# 16879           NaN          NaN                NaN    AMP-AD_1.0
# 16880           NaN          NaN                NaN    AMP-AD_1.0
# 16881           NaN          NaN                NaN    AMP-AD_1.0
# 16882           NaN          NaN                NaN    AMP-AD_1.0
# 16883           NaN          NaN                NaN    AMP-AD_1.0
# ...             ...          ...                ...           ...
# 19656           NaN          NaN                NaN    AMP-AD_1.0
# 19657           NaN          NaN                NaN    AMP-AD_1.0
# 19658           NaN          NaN                NaN    AMP-AD_1.0
# 19659   sample swap          NaN                NaN    AMP-AD_1.0
# 19660   sample swap          NaN                NaN    AMP-AD_1.0
#
# [2782 rows x 22 columns]

# %% [markdown]
# #### Drop these rows:

# %%
filter_amp_ad_1_nans = (~amp_ad_1_gold['specimenID'].isna())
amp_ad_1_gold = amp_ad_1_gold[filter_amp_ad_1_nans].reset_index(drop=True)

# %% [markdown]
# ### AMP-AD_2.0 golden biospecimen metadata:

# %%
amp_ad_2_gold = pd.concat([divco_bio, nps_bio_by_cohort]).reset_index(drop=True)

# %% [markdown]
# #### Add column `AMP-AD_phase` to denote this data belonging to AMP-AD_2.0

# %%
amp_ad_2_gold['AMP-AD_phase'] = 'AMP-AD_2.0'

# %% [markdown]
# #### Inspect for rows where `specimenID` is null:

# %%
amp_ad_2_gold[amp_ad_2_gold['specimenID'].isna()]
# Out:
# Empty DataFrame
# Columns: [individualID, specimenID, dataGenerationSite, organ, tissue, BrodmannArea, isPostMortem, sampleStatus, nucleicAcidSource, assay, specimenMetadataSource, specimenIdSource, cellType, samplingAge, samplingAgeUnits, fastingState, visitNumber, Id, entityId, AMP-AD_phase]
# Index: []

# %% [markdown]
# ### AMP_AD_1.0_2.0 golden biospecimen metadata:

# %%
amp_ad_1_2_gold = pd.concat([amp_ad_1_gold, amp_ad_2_gold]).reset_index(drop=True)

# %% [markdown]
# #### Inspecting for rows where `specimenID` is null as a sanity check:

# %%
amp_ad_1_2_gold[amp_ad_1_2_gold['specimenID'].isna()]
# Out:
# Empty DataFrame
# Columns: [individualID, specimenID, specimenIdSource, organ, tissue, BrodmannArea, sampleStatus, tissueWeight, tissueVolume, nucleicAcidSource, cellType, fastingState, isPostMortem, samplingAge, samplingAgeUnits, visitNumber, assay, exclude, excludeReason, samplingDate, Exclusion_Category, AMP-AD_phase, dataGenerationSite, specimenMetadataSource, Id, entityId]
# Index: []
#
# [0 rows x 26 columns]

# %%
amp_ad_1_2_gold
# Out:
#       individualID            specimenID specimenIdSource  organ  \
# 0         R1743384  190403-B4-A_R1743384              NaN  brain
# 1         R2670295  190403-B4-A_R2670295              NaN  brain
# 2         R4119160  190403-B4-A_R4119160              NaN  brain
# 3         R4641987  190403-B4-A_R4641987              NaN  brain
# 4         R5693901  190403-B4-A_R5693901              NaN  brain
# ...            ...                   ...              ...    ...
# 24570     R5508487              R5508487              NaN  brain
# 24571     R9380629              R9380629              NaN  brain
# 24572     R5909439              R5909439              NaN  brain
# 24573     R8594936              R8594936              NaN  brain
# 24574     R2742141              R2742141              NaN  brain
#
#                                tissue BrodmannArea sampleStatus  tissueWeight  \
# 0      dorsolateral prefrontal cortex          NaN       frozen           NaN
# 1      dorsolateral prefrontal cortex          NaN       frozen           NaN
# 2      dorsolateral prefrontal cortex          NaN       frozen           NaN
# 3      dorsolateral prefrontal cortex          NaN       frozen           NaN
# 4      dorsolateral prefrontal cortex          NaN       frozen           NaN
# ...                               ...          ...          ...           ...
# 24570  dorsolateral prefrontal cortex          NaN       frozen           NaN
# 24571  dorsolateral prefrontal cortex          NaN       frozen           NaN
# 24572  dorsolateral prefrontal cortex          NaN       frozen           NaN
# 24573  dorsolateral prefrontal cortex          NaN       frozen           NaN
# 24574  dorsolateral prefrontal cortex          NaN       frozen           NaN
#
#        tissueVolume nucleicAcidSource  ...     assay exclude  \
# 0               NaN    single nucleus  ...  scrnaSeq   False
# 1               NaN    single nucleus  ...  scrnaSeq   False
# 2               NaN    single nucleus  ...  scrnaSeq    True
# 3               NaN    single nucleus  ...  scrnaSeq   False
# 4               NaN    single nucleus  ...  scrnaSeq    True
# ...             ...               ...  ...       ...     ...
# 24570           NaN    single nucleus  ...  snrnaSeq     NaN
# 24571           NaN    single nucleus  ...  snrnaSeq     NaN
# 24572           NaN    single nucleus  ...  snrnaSeq     NaN
# 24573           NaN    single nucleus  ...  snrnaSeq     NaN
# 24574           NaN    single nucleus  ...  snrnaSeq     NaN
#
#                           excludeReason samplingDate Exclusion_Category  \
# 0                                   NaN          NaN                NaN
# 1                                   NaN          NaN                NaN
# 2      RNA genotype discordant with WGS          NaN                NaN
# 3                                   NaN          NaN                NaN
# 4                      Duplicated donor          NaN                NaN
# ...                                 ...          ...                ...
# 24570                               NaN          NaN                NaN
# 24571                               NaN          NaN                NaN
# 24572                               NaN          NaN                NaN
# 24573                               NaN          NaN                NaN
# 24574                               NaN          NaN                NaN
#
#        AMP-AD_phase dataGenerationSite specimenMetadataSource  \
# 0        AMP-AD_1.0                NaN                    NaN
# 1        AMP-AD_1.0                NaN                    NaN
# 2        AMP-AD_1.0                NaN                    NaN
# 3        AMP-AD_1.0                NaN                    NaN
# 4        AMP-AD_1.0                NaN                    NaN
# ...             ...                ...                    ...
# 24570    AMP-AD_2.0                NaN                    NaN
# 24571    AMP-AD_2.0                NaN                    NaN
# 24572    AMP-AD_2.0                NaN                    NaN
# 24573    AMP-AD_2.0                NaN                    NaN
# 24574    AMP-AD_2.0                NaN                    NaN
#
#                                          Id  entityId
# 0                                       NaN       NaN
# 1                                       NaN       NaN
# 2                                       NaN       NaN
# 3                                       NaN       NaN
# 4                                       NaN       NaN
# ...                                     ...       ...
# 24570  2b02ebb9-a0e9-4883-9e2e-7ba7350499f7       NaN
# 24571  b9ad1423-925f-40b5-8429-943386b99ef2       NaN
# 24572  10407afc-e3e9-4fea-8b37-044eab939981       NaN
# 24573  a8ddcdd4-4be0-4200-bd3c-9a84228bfb6f       NaN
# 24574  5cb3c8f2-2344-4a5e-82ed-bd4eb9597410       NaN
#
# [24575 rows x 26 columns]

# %%
counts_by_specimen_and_region = amp_ad_1_2_gold.groupby(['specimenID', 'AMP-AD_phase', 'tissue']).size().unstack('tissue', fill_value=0.0)

# %%
counts_by_specimen_and_region
# Out:
# tissue                    Head of caudate nucleus  blood  caudate nucleus  \
# specimenID  AMP-AD_phase
# 01_120405   AMP-AD_1.0                        0.0    0.0              0.0
# 02_120405   AMP-AD_1.0                        0.0    0.0              0.0
# 03_120405   AMP-AD_1.0                        0.0    0.0              0.0
# 04_120405   AMP-AD_1.0                        0.0    0.0              0.0
# 05_120405   AMP-AD_1.0                        0.0    0.0              0.0
# ...                                           ...    ...              ...
# sd_b25.131N AMP-AD_2.0                        0.0    0.0              0.0
# sd_b25.132C AMP-AD_2.0                        0.0    0.0              0.0
# sd_b25.132N AMP-AD_2.0                        0.0    0.0              0.0
# sd_b25.133C AMP-AD_2.0                        0.0    0.0              0.0
# sd_b25.133N AMP-AD_2.0                        0.0    0.0              0.0
#
# tissue                    cerebellar cortex  cerebellum  \
# specimenID  AMP-AD_phase
# 01_120405   AMP-AD_1.0                  0.0         0.0
# 02_120405   AMP-AD_1.0                  0.0         0.0
# 03_120405   AMP-AD_1.0                  0.0         0.0
# 04_120405   AMP-AD_1.0                  0.0         0.0
# 05_120405   AMP-AD_1.0                  0.0         0.0
# ...                                     ...         ...
# sd_b25.131N AMP-AD_2.0                  0.0         0.0
# sd_b25.132C AMP-AD_2.0                  0.0         0.0
# sd_b25.132N AMP-AD_2.0                  0.0         0.0
# sd_b25.133C AMP-AD_2.0                  0.0         0.0
# sd_b25.133N AMP-AD_2.0                  0.0         0.0
#
# tissue                    dorsolateral prefrontal cortex  frontal cortex  \
# specimenID  AMP-AD_phase
# 01_120405   AMP-AD_1.0                               2.0             0.0
# 02_120405   AMP-AD_1.0                               2.0             0.0
# 03_120405   AMP-AD_1.0                               2.0             0.0
# 04_120405   AMP-AD_1.0                               2.0             0.0
# 05_120405   AMP-AD_1.0                               2.0             0.0
# ...                                                  ...             ...
# sd_b25.131N AMP-AD_2.0                               1.0             0.0
# sd_b25.132C AMP-AD_2.0                               1.0             0.0
# sd_b25.132N AMP-AD_2.0                               1.0             0.0
# sd_b25.133C AMP-AD_2.0                               1.0             0.0
# sd_b25.133N AMP-AD_2.0                               1.0             0.0
#
# tissue                    frontal pole  inferior frontal gyrus  \
# specimenID  AMP-AD_phase
# 01_120405   AMP-AD_1.0             0.0                     0.0
# 02_120405   AMP-AD_1.0             0.0                     0.0
# 03_120405   AMP-AD_1.0             0.0                     0.0
# 04_120405   AMP-AD_1.0             0.0                     0.0
# 05_120405   AMP-AD_1.0             0.0                     0.0
# ...                                ...                     ...
# sd_b25.131N AMP-AD_2.0             0.0                     0.0
# sd_b25.132C AMP-AD_2.0             0.0                     0.0
# sd_b25.132N AMP-AD_2.0             0.0                     0.0
# sd_b25.133C AMP-AD_2.0             0.0                     0.0
# sd_b25.133N AMP-AD_2.0             0.0                     0.0
#
# tissue                    occipital visual cortex  parahippocampal gyrus  \
# specimenID  AMP-AD_phase
# 01_120405   AMP-AD_1.0                        0.0                    0.0
# 02_120405   AMP-AD_1.0                        0.0                    0.0
# 03_120405   AMP-AD_1.0                        0.0                    0.0
# 04_120405   AMP-AD_1.0                        0.0                    0.0
# 05_120405   AMP-AD_1.0                        0.0                    0.0
# ...                                           ...                    ...
# sd_b25.131N AMP-AD_2.0                        0.0                    0.0
# sd_b25.132C AMP-AD_2.0                        0.0                    0.0
# sd_b25.132N AMP-AD_2.0                        0.0                    0.0
# sd_b25.133C AMP-AD_2.0                        0.0                    0.0
# sd_b25.133N AMP-AD_2.0                        0.0                    0.0
#
# tissue                    posterior cingulate cortex  prefrontal cortex  \
# specimenID  AMP-AD_phase
# 01_120405   AMP-AD_1.0                           0.0                0.0
# 02_120405   AMP-AD_1.0                           0.0                0.0
# 03_120405   AMP-AD_1.0                           0.0                0.0
# 04_120405   AMP-AD_1.0                           0.0                0.0
# 05_120405   AMP-AD_1.0                           0.0                0.0
# ...                                              ...                ...
# sd_b25.131N AMP-AD_2.0                           0.0                0.0
# sd_b25.132C AMP-AD_2.0                           0.0                0.0
# sd_b25.132N AMP-AD_2.0                           0.0                0.0
# sd_b25.133C AMP-AD_2.0                           0.0                0.0
# sd_b25.133N AMP-AD_2.0                           0.0                0.0
#
# tissue                    serum  superior temporal gyrus  temporal cortex  \
# specimenID  AMP-AD_phase
# 01_120405   AMP-AD_1.0      0.0                      0.0              0.0
# 02_120405   AMP-AD_1.0      0.0                      0.0              0.0
# 03_120405   AMP-AD_1.0      0.0                      0.0              0.0
# 04_120405   AMP-AD_1.0      0.0                      0.0              0.0
# 05_120405   AMP-AD_1.0      0.0                      0.0              0.0
# ...                         ...                      ...              ...
# sd_b25.131N AMP-AD_2.0      0.0                      0.0              0.0
# sd_b25.132C AMP-AD_2.0      0.0                      0.0              0.0
# sd_b25.132N AMP-AD_2.0      0.0                      0.0              0.0
# sd_b25.133C AMP-AD_2.0      0.0                      0.0              0.0
# sd_b25.133N AMP-AD_2.0      0.0                      0.0              0.0
#
# tissue                    temporal pole  unspecified
# specimenID  AMP-AD_phase
# 01_120405   AMP-AD_1.0              0.0          0.0
# 02_120405   AMP-AD_1.0              0.0          0.0
# 03_120405   AMP-AD_1.0              0.0          0.0
# 04_120405   AMP-AD_1.0              0.0          0.0
# 05_120405   AMP-AD_1.0              0.0          0.0
# ...                                 ...          ...
# sd_b25.131N AMP-AD_2.0              0.0          0.0
# sd_b25.132C AMP-AD_2.0              0.0          0.0
# sd_b25.132N AMP-AD_2.0              0.0          0.0
# sd_b25.133C AMP-AD_2.0              0.0          0.0
# sd_b25.133N AMP-AD_2.0              0.0          0.0
#
# [19495 rows x 18 columns]

# %%
counts_by_specimen_and_region.to_csv('AMP-AD_1.0_2.0_counts_by_specimen__phase_and_region_May_7_24.csv')

# %%
summary_by_counts = amp_ad_1_2_gold.groupby(["tissue", "AMP-AD_phase"]).size()

# %%
summary_by_counts.to_csv('AMP-AD_1.0_2.0_counts_by_phase_and_region_summary_May_7_24.csv')
