# %%
import synapseclient
from synapseclient import Project, File, Folder
from synapseclient import Schema, Column, Table, Row, RowSet, as_table_columns
import pandas as pd
from pandas_plink import read_plink1_bin

# %%
syn = synapseclient.Synapse()
syn.login(authToken='eyJ0eXAiOiJKV1QiLCJraWQiOiJXN05OOldMSlQ6SjVSSzpMN1RMOlQ3TDc6M1ZYNjpKRU9VOjY0NFI6VTNJWDo1S1oyOjdaQ0s6RlBUSCIsImFsZyI6IlJTMjU2In0..Bd5Qu7JacTs1GUCFQEbha8rqMnVVNN3-2lN6ghrnWJIXZBy0-_NqqVjVBbg045WMxs7ccaySsl6NsUtRW9ZRHzyajVia4fs3pAlSINSBHqmt_w2ErnY714j_1l-6PHPKt-IJRpuuEbMYbUFCpSIlQzDvIlf9pvQSuWHci3hMWc16m1rS1cxdjQc9PRVh4I_Amw8fYJpOaX2oGqrZwmD5lvJ79nRibjMn99oN3SR7gGY06Su6_yXYGkg34CNpbDjYV_KAZ2mV0a_OKOmiUhVvKgijko5aE2fKihME4FqQwpyP642XE-2acRZWFCEjeBSgci7vUs42d9cP6NL6bNPSbg')
# Out:
# Welcome, Victor Baham!

# %%
G = read_plink1_bin('ROSMAP_arrayGenotype.bed', 'ROSMAP_arrayGenotype.bim', 'ROSMAP_arrayGenotype.fam', verbose=False)
print(G)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 G = read_plink1_bin('ROSMAP_arrayGenotype.bed', 'ROSMAP_arrayGenotype.bim', 'ROSMAP_arrayGenotype.fam', verbose=False)
#       2 print(G)
#
# File c:\Python311\Lib\site-packages\pandas_plink\_read.py:350, in read_plink1_bin(bed, bim, fam, verbose, ref, chunk)
#     347 else:
#     348     raise ValueError("Unknown reference allele.")
# --> 350 G = _read_file(
#     351     bed_files, lambda f: _read_bed(f, nsamples, nmarkers[f], ref_al, chunk), pbar
#     352 )
#     353 G = concatenate(G, axis=1)
#     354 assert isinstance(G, Array)
#
# File c:\Python311\Lib\site-packages\pandas_plink\_read.py:374, in _read_file(files, read_func, pbar)
#     372 data: list[T] = []
#     373 for f in files:
# --> 374     data.append(read_func(f))
#     375     pbar.update(1)
#     376 return data
#
# ...
