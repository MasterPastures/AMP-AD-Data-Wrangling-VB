# %%
import synapseclient
from synapseclient import Project, File, Folder
from synapseclient import Schema, Column, Table, Row, RowSet, as_table_columns
import itertools
import pandas as pd
import numpy as np

# %%
syn = synapseclient.Synapse()
syn.login()
# Out:
# Welcome, Victor Baham!

# %% [markdown]
# #### Issue: [syn52368902](https://www.synapse.org/Synapse:syn52368902) does not contain `libraryID` data
# #### BUT! Hansruedi provided a manifest with libraryIDs, which I applied as annotations to all files besides the `snRNAseq - raw Smart-seq2` files
# #### Solution: fill column `libraryID` in [syn52368902](https://www.synapse.org/Synapse:syn52368902) with `libraryID` annotations on the `snRNAseq - raw Smart-seq2` files

# %% [markdown]
# #### Update: renaming a column in a FileView schema apparently keeps the previously titled annotation and adds the new one on all files!

# %% [markdown]
# #### Get all MIT_ROSMAP_Multiomics multi-region snRNAseq - raw 10x genomics files

# %%
# MRM multi-region snRNAseq - raw 10x genomics files
schema_mrm_mr_snrna_raw_10x = syn.get('syn52420188')
results_mrm_mr_snrna_raw_10x = syn.tableQuery(f"SELECT * FROM {schema_mrm_mr_snrna_raw_10x.id}")  
mrm_mr_snrna_raw_10x = pd.read_csv(results_mrm_mr_snrna_raw_10x.filepath)
# Out:
# Downloading files: 100%|████████| 976k/976k [00:00<00:00, 3.10MB/s, syn52420188]
# Downloaded syn52420188 to /Users/vbaham/.synapseCache/842/145038842/SYNAPSE_TABLE_QUERY_145038842.csv
# Downloading files: 100%|████████| 976k/976k [00:00<00:00, 2.99MB/s, syn52420188]

# %% [markdown]
# #### Get all MIT_ROSMAP_Multiomics snRNAseq - raw 10x genomics files

# %%
# MRM snRNAseq - raw 10x genomics files 
schema_mrm_snrna_raw_10x = syn.get('syn52420143')
results_mrm_snrna_raw_10x = syn.tableQuery(f"SELECT * FROM {schema_mrm_snrna_raw_10x.id}")  
mrm_snrna_raw_10x = pd.read_csv(results_mrm_snrna_raw_10x.filepath)
# Out:
# Downloading files: 100%|██████| 1.85M/1.85M [00:00<00:00, 10.4MB/s, syn52420143]
# Downloaded syn52420143 to /Users/vbaham/.synapseCache/845/145038845/SYNAPSE_TABLE_QUERY_145038845.csv
# Downloading files: 100%|██████| 1.85M/1.85M [00:00<00:00, 9.92MB/s, syn52420143]

# %% [markdown]
# #### Get all MIT_ROSMAP_Multiomics snRNAseq - raw Smart-seq2 files

# %%
# MRM snRNAseq - raw Smart-seq2 files
schema_mrm_snrna_raw_ss2 = syn.get('syn52420161')
results_mrm_snrna_raw_ss2 = syn.tableQuery(f"SELECT * FROM {schema_mrm_snrna_raw_ss2.id}")  
mrm_snrna_raw_ss2 = pd.read_csv(results_mrm_snrna_raw_ss2.filepath)
# Out:
# Downloading files:  92%|█████▌| 2.10M/2.29M [00:00<00:00, 10.6MB/s, syn52420161]
# Downloaded syn52420161 to /Users/vbaham/.synapseCache/853/145038853/SYNAPSE_TABLE_QUERY_145038853.csv
# Downloading files: 100%|██████| 2.29M/2.29M [00:00<00:00, 10.8MB/s, syn52420161]

# %% [markdown]
# #### Functions to get `libraryID` from file names [customized to each use case of filename formats due to time constraints]
#
# `get_lib_id_S` is for:
# * MIT_ROSMAP_Multiomics multi-region snRNAseq - raw 10x genomics files
# * MIT_ROSMAP_Multiomics snRNAseq - raw 10x genomics files
#
# `get_lib_id_N` is for:
# * MIT_ROSMAP_Multiomics snRNAseq - raw Smart-seq2 files

# %%
def get_lib_id_S(name):
    s_idx = name.index('S')
    return name[:s_idx-1]

def get_lib_id_N(name):
    d_idx = name.index('D')
    n_idx = name.index('N')
    return name[d_idx:n_idx-1]

mrm_mr_snrna_raw_10x['libraryID'] = mrm_mr_snrna_raw_10x['name'].map(get_lib_id_S)
mrm_snrna_raw_10x['libraryID'] = mrm_snrna_raw_10x['name'].map(get_lib_id_S)
mrm_snrna_raw_ss2['libraryID'] = mrm_snrna_raw_ss2['name'].map(get_lib_id_N)

# %%
mrm_mr_snrna_raw_10x
# Out:
#         ROW_ID  ROW_VERSION                              ROW_ETAG  \
# 0     52409373            1  b7878e0b-68af-4a9b-809a-eacb8829b3aa
# 1     52409374            1  1ebffa32-b4bb-48ed-a6f1-746d65bec4ca
# 2     52409375            1  2dc8e946-d8b6-469c-b3e6-8e9247010dde
# 3     52409376            1  87aac540-daa2-40e3-a570-068100bbb9f6
# 4     52409377            1  b0ede12c-a6f2-4678-80f6-22a1dff7ed04
# ...        ...          ...                                   ...
# 2593  52416533            1  32f0e8d6-b1a0-4272-bd10-6c7cbdcb83ea
# 2594  52416534            1  fe7f4e3f-07db-46f0-974d-6c059b257418
# 2595  52416535            1  9754001e-1d9e-4445-bcf9-a8a0659f15ff
# 2596  52416537            1  60086ddd-e4d9-40c2-ae2e-32c04e5d40db
# 2597  52416542            1  bb5002cf-93e8-45a7-aaa8-f143967895d2
#
#                id                               name   assay consortium  \
# 0     syn52409373   D19-8387_S1_L001_I1_001.fastq.gz  rnaSeq       CDCP
# 1     syn52409374   D19-8387_S1_L002_I1_001.fastq.gz  rnaSeq       CDCP
# 2     syn52409375   D19-8388_S2_L002_I1_001.fastq.gz  rnaSeq       CDCP
# 3     syn52409376   D19-8388_S2_L001_I1_001.fastq.gz  rnaSeq       CDCP
# 4     syn52409377   D19-8387_S1_L001_R1_001.fastq.gz  rnaSeq       CDCP
# ...           ...                                ...     ...        ...
# 2593  syn52416533  D19-4645_S29_L001_R2_001.fastq.gz  rnaSeq       CDCP
# 2594  syn52416534  D19-4645_S29_L002_R2_001.fastq.gz  rnaSeq       CDCP
# 2595  syn52416535  D19-4648_S32_L001_R2_001.fastq.gz  rnaSeq       CDCP
# 2596  syn52416537  D19-4647_S31_L002_R2_001.fastq.gz  rnaSeq       CDCP
# 2597  syn52416542  D19-4648_S32_L002_R2_001.fastq.gz  rnaSeq       CDCP
#
#      dataSubtype        dataType fileFormat  ...         tissue  \
# 0            raw  geneExpression      fastq  ...  angular gyrus
# 1            raw  geneExpression      fastq  ...  angular gyrus
# 2            raw  geneExpression      fastq  ...  angular gyrus
# 3            raw  geneExpression      fastq  ...  angular gyrus
# 4            raw  geneExpression      fastq  ...  angular gyrus
# ...          ...             ...        ...  ...            ...
# 2593         raw  geneExpression      fastq  ...    hippocampus
# 2594         raw  geneExpression      fastq  ...    hippocampus
# 2595         raw  geneExpression      fastq  ...    hippocampus
# 2596         raw  geneExpression      fastq  ...    hippocampus
# 2597         raw  geneExpression      fastq  ...    hippocampus
#
#      nucleicAcidSource  referenceSet  libraryPrep    runType  organ  \
# 0       single nucleus        GRCh38          10x  pairedEnd  brain
# 1       single nucleus        GRCh38          10x  pairedEnd  brain
# 2       single nucleus        GRCh38          10x  pairedEnd  brain
# 3       single nucleus        GRCh38          10x  pairedEnd  brain
# 4       single nucleus        GRCh38          10x  pairedEnd  brain
# ...                ...           ...          ...        ...    ...
# 2593    single nucleus        GRCh38          10x        NaN  brain
# 2594    single nucleus        GRCh38          10x        NaN  brain
# 2595    single nucleus        GRCh38          10x  pairedEnd  brain
# 2596    single nucleus        GRCh38          10x        NaN  brain
# 2597    single nucleus        GRCh38          10x  pairedEnd  brain
#
#                  platform species libraryID libraryBatch
# 0     IlluminaNovaseq6000   Human  D19-8387     D19-8387
# 1     IlluminaNovaseq6000   Human  D19-8387     D19-8387
# 2     IlluminaNovaseq6000   Human  D19-8388     D19-8388
# 3     IlluminaNovaseq6000   Human  D19-8388     D19-8388
# 4     IlluminaNovaseq6000   Human  D19-8387     D19-8387
# ...                   ...     ...       ...          ...
# 2593  IlluminaNovaseq6000   Human  D19-4645     D19-4645
# 2594  IlluminaNovaseq6000   Human  D19-4645     D19-4645
# 2595  IlluminaNovaseq6000   Human  D19-4648     D19-4648
# 2596  IlluminaNovaseq6000   Human  D19-4647     D19-4647
# 2597  IlluminaNovaseq6000   Human  D19-4648     D19-4648
#
# [2598 rows x 28 columns]

# %%
mrm_snrna_raw_10x
# Out:
#         ROW_ID  ROW_VERSION                              ROW_ETAG  \
# 0     52368872            2  da05e848-97ad-4341-8623-0aa2928052cd
# 1     52368873            2  5c19c26e-c1b1-4316-9cbe-9fb08de84948
# 2     52368874            2  77c59728-4a23-4664-8aaf-78413cee76b6
# 3     52368875            2  7cdeedad-51b8-4087-8c24-b4d58303e0ff
# 4     52368876            2  6d2d6d22-8a89-4de2-b9f8-e45de827193d
# ...        ...          ...                                   ...
# 4873  52404503            1  64d7978f-b543-4e38-9e3e-9efdcfe0eeeb
# 4874  52404504            1  4033f68d-dbcf-43cd-b5a3-b3447dc09a36
# 4875  52404505            1  288d26ee-0ce9-42f6-9f7c-be92ad4917e0
# 4876  52404506            1  87ea3a39-39d5-44ee-987f-c0025ed566dd
# 4877  52404507            1  66cb03f1-0108-40e7-9c49-bac4d2ddb98f
#
#                id                                 name   assay consortium  \
# 0     syn52368872  D19-10914_1_S1_L001_I1_001.fastq.gz  rnaSeq       CDCP
# 1     syn52368873  D19-10914_1_S1_L002_I1_001.fastq.gz  rnaSeq       CDCP
# 2     syn52368874  D19-10914_2_S2_L001_I1_001.fastq.gz  rnaSeq       CDCP
# 3     syn52368875  D19-10914_2_S2_L002_I1_001.fastq.gz  rnaSeq       CDCP
# 4     syn52368876  D19-10914_1_S1_L001_R1_001.fastq.gz  rnaSeq       CDCP
# ...           ...                                  ...     ...        ...
# 4873  syn52404503     D19-2488_S4_L004_R1_001.fastq.gz  rnaSeq       CDCP
# 4874  syn52404504     D19-2488_S4_L002_R1_001.fastq.gz  rnaSeq       CDCP
# 4875  syn52404505     D19-2488_S4_L003_R2_001.fastq.gz  rnaSeq       CDCP
# 4876  syn52404506     D19-2488_S4_L004_R2_001.fastq.gz  rnaSeq       CDCP
# 4877  syn52404507     D19-2488_S4_L002_R2_001.fastq.gz  rnaSeq       CDCP
#
#      dataSubtype        dataType fileFormat  ...             tissue  \
# 0            raw  geneExpression      fastq  ...  prefrontal cortex
# 1            raw  geneExpression      fastq  ...  prefrontal cortex
# 2            raw  geneExpression      fastq  ...  prefrontal cortex
# 3            raw  geneExpression      fastq  ...  prefrontal cortex
# 4            raw  geneExpression      fastq  ...  prefrontal cortex
# ...          ...             ...        ...  ...                ...
# 4873         raw  geneExpression      fastq  ...  prefrontal cortex
# 4874         raw  geneExpression      fastq  ...  prefrontal cortex
# 4875         raw  geneExpression      fastq  ...  prefrontal cortex
# 4876         raw  geneExpression      fastq  ...  prefrontal cortex
# 4877         raw  geneExpression      fastq  ...  prefrontal cortex
#
#      nucleicAcidSource  referenceSet  libraryPrep    runType  organ  \
# 0       single nucleus        GRCh38          10x  pairedEnd  brain
# 1       single nucleus        GRCh38          10x  pairedEnd  brain
# 2       single nucleus        GRCh38          10x  pairedEnd  brain
# 3       single nucleus        GRCh38          10x  pairedEnd  brain
# 4       single nucleus        GRCh38          10x  pairedEnd  brain
# ...                ...           ...          ...        ...    ...
# 4873    single nucleus        GRCh38          10x  pairedEnd  brain
# 4874    single nucleus        GRCh38          10x  pairedEnd  brain
# 4875    single nucleus        GRCh38          10x  pairedEnd  brain
# 4876    single nucleus        GRCh38          10x  pairedEnd  brain
# 4877    single nucleus        GRCh38          10x  pairedEnd  brain
#
#                  platform species    libraryID libraryBatch
# 0     IlluminaNovaseq6000   Human  D19-10914_1  D19-10914_1
# 1     IlluminaNovaseq6000   Human  D19-10914_1  D19-10914_1
# 2     IlluminaNovaseq6000   Human  D19-10914_2  D19-10914_2
# 3     IlluminaNovaseq6000   Human  D19-10914_2  D19-10914_2
# 4     IlluminaNovaseq6000   Human  D19-10914_1  D19-10914_1
# ...                   ...     ...          ...          ...
# 4873  IlluminaNovaseq6000   Human     D19-2488     D19-2488
# 4874  IlluminaNovaseq6000   Human     D19-2488     D19-2488
# 4875  IlluminaNovaseq6000   Human     D19-2488     D19-2488
# 4876  IlluminaNovaseq6000   Human     D19-2488     D19-2488
# 4877  IlluminaNovaseq6000   Human     D19-2488     D19-2488
#
# [4878 rows x 28 columns]

# %%
mrm_snrna_raw_ss2
# Out:
#         ROW_ID  ROW_VERSION                              ROW_ETAG  \
# 0     52400111            8  832ccf4e-7327-42f3-84c1-a2a633605f2f
# 1     52400112            8  41521fc6-c63a-4b6c-9d37-61b496e0dd17
# 2     52400113            8  40c32629-ee4c-42d8-a1f9-576e00058bf1
# 3     52400115            8  38d8b4b6-e23a-43ee-8d6f-bb41fe5a054f
# 4     52400116            8  b2023690-2b99-4437-942b-20e520dd9da1
# ...        ...          ...                                   ...
# 5816  52406887            1  b867213c-8bdf-4597-a2c3-4f4a8b434085
# 5817  52406888            1  634d8727-dc22-4c98-9117-2923194f5ec6
# 5818  52406889            1  37c76535-fd89-42af-9eaf-6f9248cf2235
# 5819  52406890            1  fc66b5d9-c315-4556-aff4-124b205a359b
# 5820  52406892            1  15810938-6890-4ad8-a20b-5b086844311d
#
#                id                                       name     assay  \
# 0     syn52400111  170725Tsa_D17-155463_NA_sequence.fastq.gz  snrnaSeq
# 1     syn52400112  170725Tsa_D17-155523_NA_sequence.fastq.gz  snrnaSeq
# 2     syn52400113  170725Tsa_D17-155528_NA_sequence.fastq.gz  snrnaSeq
# 3     syn52400115  170725Tsa_D17-155492_NA_sequence.fastq.gz  snrnaSeq
# 4     syn52400116  170725Tsa_D17-155515_NA_sequence.fastq.gz  snrnaSeq
# ...           ...                                        ...       ...
# 5816  syn52406887  170725Tsa_D17-154365_NA_sequence.fastq.gz  snrnaSeq
# 5817  syn52406888  170725Tsa_D17-154321_NA_sequence.fastq.gz  snrnaSeq
# 5818  syn52406889  170725Tsa_D17-154332_NA_sequence.fastq.gz  snrnaSeq
# 5819  syn52406890  170725Tsa_D17-154301_NA_sequence.fastq.gz  snrnaSeq
# 5820  syn52406892  170725Tsa_D17-154349_NA_sequence.fastq.gz  snrnaSeq
#
#      consortium dataSubtype        dataType fileFormat  ...  \
# 0        AMP-AD         raw  geneExpression      fastq  ...
# 1        AMP-AD         raw  geneExpression      fastq  ...
# 2        AMP-AD         raw  geneExpression      fastq  ...
# 3        AMP-AD         raw  geneExpression      fastq  ...
# 4        AMP-AD         raw  geneExpression      fastq  ...
# ...         ...         ...             ...        ...  ...
# 5816     AMP-AD         raw  geneExpression      fastq  ...
# 5817     AMP-AD         raw  geneExpression      fastq  ...
# 5818     AMP-AD         raw  geneExpression      fastq  ...
# 5819     AMP-AD         raw  geneExpression      fastq  ...
# 5820     AMP-AD         raw  geneExpression      fastq  ...
#
#                  tissue nucleicAcidSource  referenceSet  libraryPrep  \
# 0     prefrontal cortex    single nucleus        GRCh38   Smart-seq2
# 1     prefrontal cortex    single nucleus        GRCh38   Smart-seq2
# 2     prefrontal cortex    single nucleus        GRCh38   Smart-seq2
# 3     prefrontal cortex    single nucleus        GRCh38   Smart-seq2
# 4     prefrontal cortex    single nucleus        GRCh38   Smart-seq2
# ...                 ...               ...           ...          ...
# 5816  prefrontal cortex    single nucleus        GRCh38   Smart-seq2
# 5817  prefrontal cortex    single nucleus        GRCh38   Smart-seq2
# 5818  prefrontal cortex    single nucleus        GRCh38   Smart-seq2
# 5819  prefrontal cortex    single nucleus        GRCh38   Smart-seq2
# 5820  prefrontal cortex    single nucleus        GRCh38   Smart-seq2
#
#         runType  organ             platform species   libraryID libraryBatch
# 0     singleEnd  brain  IlluminaNovaseq6000   Human  D17-155463   D17-155463
# 1     singleEnd  brain  IlluminaNovaseq6000   Human  D17-155523   D17-155523
# 2     singleEnd  brain  IlluminaNovaseq6000   Human  D17-155528   D17-155528
# 3     singleEnd  brain  IlluminaNovaseq6000   Human  D17-155492   D17-155492
# 4     singleEnd  brain  IlluminaNovaseq6000   Human  D17-155515   D17-155515
# ...         ...    ...                  ...     ...         ...          ...
# 5816  singleEnd  brain  IlluminaNovaseq6000   Human  D17-154365   D17-154365
# 5817  singleEnd  brain  IlluminaNovaseq6000   Human  D17-154321   D17-154321
# 5818  singleEnd  brain  IlluminaNovaseq6000   Human  D17-154332   D17-154332
# 5819  singleEnd  brain  IlluminaNovaseq6000   Human  D17-154301   D17-154301
# 5820  singleEnd  brain  IlluminaNovaseq6000   Human  D17-154349   D17-154349
#
# [5821 rows x 28 columns]

# %% [markdown]
# #### Delete incorrect `libraryBatch` annotation that is inconsistent with assay metadata file

# %%
mrm_mr_snrna_raw_10x['libraryBatch'] = ''
mrm_snrna_raw_10x['libraryBatch'] = ''
mrm_snrna_raw_ss2['libraryBatch'] = ''

# %% [markdown]
# #### Store changes in Synapse

# %%
syn.store(Table('syn52420188', mrm_mr_snrna_raw_10x))
syn.store(Table('syn52420143', mrm_snrna_raw_10x))
syn.store(Table('syn52420161', mrm_snrna_raw_ss2))
# Out:
# Uploading: 100%|██████████████████| 809k/809k [00:00<00:00, 1.06MB/s, table.csv]
# Uploading: 100%|████████████████| 1.54M/1.54M [00:00<00:00, 1.73MB/s, table.csv]
# Uploading: 100%|████████████████| 1.97M/1.97M [00:01<00:00, 1.37MB/s, table.csv]

# %% [markdown]
# ### Fill in `libraryBatch` column in MIT ROSMAP Multiomics snRNAseq metadata file

# %% [markdown]
# #### First, concatenate all dfs to map specimenID to libraryBatch:

# %%
mrm_all = pd.concat([mrm_mr_snrna_raw_10x, mrm_snrna_raw_10x, mrm_snrna_raw_ss2],
                   axis=0)
spec_to_lib = dict(zip(mrm_all['specimenID'], mrm_all['libraryID']))

# %% [markdown]
# #### Get df representation of [syn52368902](https://www.synapse.org/Synapse:syn52368902):

# %%
mrm_snrna_meta = pd.read_csv(syn.get('syn52368902').path)

# %%
mrm_snrna_meta['libraryID'] = mrm_snrna_meta['specimenID'].apply(lambda x: spec_to_lib.get(x) 
                                                           if x in spec_to_lib.keys()
                                                                else x)

# %%
mrm_snrna_meta
# Out:
#        specimenID               platform     libraryPrep  \
# 0      R2626559.1  Illumina NovaSeq 6000  polyAselection
# 1      R9936070.1  Illumina NovaSeq 6000  polyAselection
# 2      R2367199.1  Illumina NovaSeq 6000  polyAselection
# 3      R9891381.1  Illumina NovaSeq 6000  polyAselection
# 4      R9033345.1  Illumina NovaSeq 6000  polyAselection
# ...           ...                    ...             ...
# 6243  R9551808.83              HiSeq2000             NaN
# 6244  R9551808.84              HiSeq2000             NaN
# 6245  R9551808.85              HiSeq2000             NaN
# 6246  R9551808.86              HiSeq2000             NaN
# 6247   R9551808.9              HiSeq2000             NaN
#
#      libraryPreparationMethod  isStranded readStrandOrigin    runType  \
# 0                         10x         1.0          reverse  pairedEnd
# 1                         10x         1.0          reverse  pairedEnd
# 2                         10x         1.0          reverse  pairedEnd
# 3                         10x         1.0          reverse  pairedEnd
# 4                         10x         1.0          reverse  pairedEnd
# ...                       ...         ...              ...        ...
# 6243               Smart-seq2         NaN              NaN  singleEnd
# 6244               Smart-seq2         NaN              NaN  singleEnd
# 6245               Smart-seq2         NaN              NaN  singleEnd
# 6246               Smart-seq2         NaN              NaN  singleEnd
# 6247               Smart-seq2         NaN              NaN  singleEnd
#
#       readLength     assay  RIN  ...  sampleBarcode  totalReads  \
# 0             91       NaN  NaN  ...            NaN         NaN
# 1             91       NaN  NaN  ...            NaN         NaN
# 2             91       NaN  NaN  ...            NaN         NaN
# 3             91       NaN  NaN  ...            NaN         NaN
# 4             91       NaN  NaN  ...            NaN         NaN
# ...          ...       ...  ...  ...            ...         ...
# 6243          40  snrnaSeq  NaN  ...            NaN         NaN
# 6244          40  snrnaSeq  NaN  ...            NaN         NaN
# 6245          40  snrnaSeq  NaN  ...            NaN         NaN
# 6246          40  snrnaSeq  NaN  ...            NaN         NaN
# 6247          40  snrnaSeq  NaN  ...            NaN         NaN
#
#       validBarcodeReads  numberCells  medianGenes  medianUMIs   libraryID  \
# 0                   NaN          NaN          NaN         NaN    D19-2488
# 1                   NaN          NaN          NaN         NaN    D19-2467
# 2                   NaN          NaN          NaN         NaN    D19-5948
# 3                   NaN          NaN          NaN         NaN    D19-4792
# 4                   NaN          NaN          NaN         NaN    D19-4159
# ...                 ...          ...          ...         ...         ...
# 6243                NaN          NaN          NaN         NaN  D17-154365
# 6244                NaN          NaN          NaN         NaN  D17-154301
# 6245                NaN          NaN          NaN         NaN  D17-154349
# 6246                NaN          NaN          NaN         NaN  D17-154332
# 6247                NaN          NaN          NaN         NaN  D17-154321
#
#       referenceSet  libraryVersion  DV200
# 0              NaN             NaN    NaN
# 1              NaN             NaN    NaN
# 2              NaN             NaN    NaN
# 3              NaN             NaN    NaN
# 4              NaN             NaN    NaN
# ...            ...             ...    ...
# 6243           NaN             NaN    NaN
# 6244           NaN             NaN    NaN
# 6245           NaN             NaN    NaN
# 6246           NaN             NaN    NaN
# 6247           NaN             NaN    NaN
#
# [6248 rows x 24 columns]

# %% [markdown]
# #### Write this to a file with the same name as the current snrnaSeq assay metadata file, then upload this new file to Synapse but leave the `libraryBatch` column as is

# %%
mrm_snrna_meta.to_csv('MIT_ROSMAP_Multiomics_assay_snRNAseq_metadata.csv')
